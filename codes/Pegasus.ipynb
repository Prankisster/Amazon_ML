# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# import requests
# from transformers import PegasusTokenizer, PegasusForConditionalGeneration

# # Load the PEGASUS model and tokenizer
# tokenizer = PegasusTokenizer.from_pretrained('google/pegasus-xsum')
# model = PegasusForConditionalGeneration.from_pretrained('google/pegasus-xsum')

# # Fetch the news article
# url = 'https://www.bbc.com/news/world-europe-56801538'
# r = requests.get(url)
# text = r.text

# # Preprocess the text
# text = text.split('\n')
# text = [t for t in text if t and not t.isspace()]
# text = ' '.join(text)

# # Tokenize the text
# inputs = tokenizer.encode(text, return_tensors='pt')

# # Generate the summary
# summary_ids = model.generate(inputs, max_length=60, min_length=10, length_penalty=2.0)
# summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# print('Original text:')
# print(text)
# print('\nSummary:')
# print(summary)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-e669201b8d35> in <cell line: 5>()
#       3
#       4 # Load the PEGASUS model and tokenizer
# ----> 5 tokenizer = PegasusTokenizer.from_pretrained('google/pegasus-xsum')
#       6 model = PegasusForConditionalGeneration.from_pretrained('google/pegasus-xsum')
#       7
#
# TypeError: 'NoneType' object is not callable

# %%
import torch
from transformers import PegasusTokenizer, PegasusForConditionalGeneration

# Load the Pegasus tokenizer and model
tokenizer = PegasusTokenizer.from_pretrained('google/pegasus-xsum')
model = PegasusForConditionalGeneration.from_pretrained('google/pegasus-xsum')

# Define the input text to summarize
input_text = "The quick brown fox jumped over the lazy dog. The dog didn't seem to care much."

# Tokenize the input text
input_ids = tokenizer.encode(input_text, return_tensors='pt')

# Generate the summary
summary_ids = model.generate(input_ids, max_length=50, min_length=10, length_penalty=2.0)
summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# Print the original text and the summary
print("Input Text:")
print(input_text)
print("\nSummary:")
print(summary)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-52803f8b181e> in <cell line: 5>()
#       3
#       4 # Load the Pegasus tokenizer and model
# ----> 5 tokenizer = PegasusTokenizer.from_pretrained('google/pegasus-xsum')
#       6 model = PegasusForConditionalGeneration.from_pretrained('google/pegasus-xsum')
#       7
#
# TypeError: 'NoneType' object is not callable
