# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Clean_data_with_nan_only.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1211238 entries, 0 to 1211237
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   Unnamed: 0               1211238 non-null  int64
#  1   PRODUCT_ID               1211238 non-null  int64
#  2   PRODUCT_TYPE_ID          1211238 non-null  int64
#  3   PRODUCT_LENGTH           1211238 non-null  float64
#  4   processed_description    53393 non-null    object
#  5   processed_bullet_points  373739 non-null   object
#  6   processed_title          1210395 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 64.7+ MB

# %%
data
# Out:
#         Unnamed: 0  PRODUCT_ID PRODUCT_TYPE_ID  PRODUCT_LENGTH  \
# 0                2     2765088            7537      748.031495
# 1                3     1594019            2996      787.401574
# 2                5     2152929            5725      950.000000
# 3                7     2026580            6030      984.251967
# 4                9     2998633            8201      393.700787
# ...            ...         ...             ...             ...
# 1232740    2249686     1898841           12556      600.000000
# 1232741    2249689     1616561            2879     1200.000000
# 1232742    2249694     2766635            3413      125.984252
# 1232743    2249695     1987786            1574     1200.000000
# 1232744    2249697     1072666            7367     2000.000000
#
#                                      processed_description  \
# 0        Specifications Color Red Material Aluminium Vo...
# 1        AISHAH Womens Lycra Cotton Ankel Leggings Bran...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2249698 entries, 0 to 2249697
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   PRODUCT_ID       int64
#  1   TITLE            object
#  2   BULLET_POINTS    object
#  3   DESCRIPTION      object
#  4   PRODUCT_TYPE_ID  int64
#  5   PRODUCT_LENGTH   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 103.0+ MB

# %%
data_test = pd.read_csv('test.csv')
data_test.head()
# Out:
#    PRODUCT_ID                                              TITLE  \
# 0      604373  Manuel d'Héliogravure Et de Photogravure En Re...
# 1     1729783  DCGARING Microfiber Throw Blanket Warm Fuzzy P...
# 2     1871949  I-Match Auto Parts Front License Plate Bracket...
# 3     1107571  PinMart Gold Plated Excellence in Service 1 Ye...
# 4      624253  Visual Mathematics, Illustrated by the TI-92 a...
#
#                                        BULLET_POINTS  \
# 0                                                NaN
# 1  [QUALITY GUARANTEED: Luxury cozy plush polyest...
# 2  [Front License Plate Bracket Made Of Plastic,D...
# 3  [Available as a single item or bulk packed. Se...
# 4                                                NaN
#
#                                          DESCRIPTION  PRODUCT_TYPE_ID
# 0                                                NaN             6142
# 1  <b>DCGARING Throw Blanket</b><br><br> <b>Size ...             1622
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0                      0
# PRODUCT_ID                      0
# PRODUCT_TYPE_ID            194285
# PRODUCT_LENGTH             194290
# processed_description      196450
# processed_bullet_points    195119
# processed_title            194346
# dtype: int64

# %%
data
# Out:
#         Unnamed: 0  PRODUCT_ID PRODUCT_TYPE_ID  PRODUCT_LENGTH  \
# 0                2     2765088            7537      748.031495
# 1                3     1594019            2996      787.401574
# 2                5     2152929            5725      950.000000
# 3                7     2026580            6030      984.251967
# 4                9     2998633            8201      393.700787
# ...            ...         ...             ...             ...
# 1232740    2249686     1898841           12556      600.000000
# 1232741    2249689     1616561            2879     1200.000000
# 1232742    2249694     2766635            3413      125.984252
# 1232743    2249695     1987786            1574     1200.000000
# 1232744    2249697     1072666            7367     2000.000000
#
#                                      processed_description  \
# 0        Specifications Color Red Material Aluminium Vo...
# 1        AISHAH Womens Lycra Cotton Ankel Leggings Bran...
# ...

# %%
data_without_nan = data.dropna(subset=['processed_title','processed_bullet_points','processed_description'])
data_without_nan
# Out:
#         Unnamed: 0  PRODUCT_ID PRODUCT_TYPE_ID  PRODUCT_LENGTH  \
# 0                2     2765088            7537      748.031495
# 1                3     1594019            2996      787.401574
# 2                5     2152929            5725      950.000000
# 3                7     2026580            6030      984.251967
# 4                9     2998633            8201      393.700787
# ...            ...         ...             ...             ...
# 1232740    2249686     1898841           12556      600.000000
# 1232741    2249689     1616561            2879     1200.000000
# 1232742    2249694     2766635            3413      125.984252
# 1232743    2249695     1987786            1574     1200.000000
# 1232744    2249697     1072666            7367     2000.000000
#
#                                      processed_description  \
# 0        Specifications Color Red Material Aluminium Vo...
# 1        AISHAH Womens Lycra Cotton Ankel Leggings Bran...
# ...

# %%
from bs4 import BeautifulSoup
import re
import string

def remove_BS(text):
    # Remove HTML Tags 
    soup = BeautifulSoup(text, "html.parser")
    cleaned_text = soup.get_text()

    # Remove Special Characters 
    pattern = r'[^a-zA-Z0-9\s]'
    cleaned_text = re.sub(pattern, '', cleaned_text)
    # return re.sub(pattern, '', cleaned_text)

    # Remove punctations
    text  = "".join([char for char in cleaned_text if char not in string.punctuation])
    text = re.sub('[0-9]+', '', text)
    cleaned_text = re.sub('\n' , "", text)

    return cleaned_text

# # Example usage
# html_text = "<p>This is an example <b>HTML</b> text with <a href='https://example.com'>link</a>.</p>"
# me = '<p><strong>!!!!!Aluminum Foil Stickers-good...... ???ASDASD...,,,,as.kitchen helper for mom and wife.&nbsp;</strong><br><br><strong>Specification: &nbsp;</strong><br><strong>'
# me = "â˜…Sizeï¼šXS=US (4-6) S=US(4-8), M=US(10-14), L=US(16-20), XL=US(18-22ï¼‰ï¼ŒOversized style sweatersï¼Œif between size, long torso choose size up.,â˜…Designï¼šTurtle cowl neckï¼Œlong batwing sleeveï¼Œhigh low split hemï¼Œsolid colorï¼Œtunic top sweaterï¼Œknitwear casual styleï¼Œoversized sweater.,â˜…Occasion: Outdoor wearing, Casual,Office; Great with leggings, high heels, boots etc,â˜…Material:The asymmetric hem sweater made of 50% viscose 30% nylon and 20% Ployesterï¼Œchunky sweaterï¼Œcasual comfy pulloversï¼ŒLILLUSORY high quality sweaters.,â˜…Washing Instruction: Hand wash recommended.Steam Iron."
# cleaned_text = remove_BS(me)

data_without_nan['DESCRIPTION'] = data_without_nan['DESCRIPTION'].apply(remove_BS)
data_without_nan.head()
# print(cleaned_text)
# Out:
# /var/folders/6v/jd1m090n7m322nvh1vy2fbjh0000gp/T/ipykernel_92364/3283176944.py:7: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# /var/folders/6v/jd1m090n7m322nvh1vy2fbjh0000gp/T/ipykernel_92364/3283176944.py:7: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
#    PRODUCT_ID                                              TITLE  \
# 2     2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3     1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 5     2152929  HINS Metal Bucket Shape Plant Pot for Indoor &...
# 7     2026580  Delavala Self Adhesive Kitchen Backsplash Wall...
# ...

# %%
from bs4 import BeautifulSoup
import re
import string

def remove_BS(text):
    # Remove HTML Tags 
    soup = BeautifulSoup(text, "html.parser")
    cleaned_text = soup.get_text()

    # Remove Special Characters 
    pattern = r'[^a-zA-Z0-9\s]'
    cleaned_text = re.sub(pattern, '', cleaned_text)
    # return re.sub(pattern, '', cleaned_text)

    # Remove punctations
    text  = "".join([char for char in cleaned_text if char not in string.punctuation])
    text = re.sub('[0-9]+', '', text)
    cleaned_text = re.sub('\n' , "", text)

    return cleaned_text

# # Example usage
# html_text = "<p>This is an example <b>HTML</b> text with <a href='https://example.com'>link</a>.</p>"
# me = '<p><strong>!!!!!Aluminum Foil Stickers-good...... ???ASDASD...,,,,as.kitchen helper for mom and wife.&nbsp;</strong><br><br><strong>Specification: &nbsp;</strong><br><strong>'
# me = "â˜…Sizeï¼šXS=US (4-6) S=US(4-8), M=US(10-14), L=US(16-20), XL=US(18-22ï¼‰ï¼ŒOversized style sweatersï¼Œif between size, long torso choose size up.,â˜…Designï¼šTurtle cowl neckï¼Œlong batwing sleeveï¼Œhigh low split hemï¼Œsolid colorï¼Œtunic top sweaterï¼Œknitwear casual styleï¼Œoversized sweater.,â˜…Occasion: Outdoor wearing, Casual,Office; Great with leggings, high heels, boots etc,â˜…Material:The asymmetric hem sweater made of 50% viscose 30% nylon and 20% Ployesterï¼Œchunky sweaterï¼Œcasual comfy pulloversï¼ŒLILLUSORY high quality sweaters.,â˜…Washing Instruction: Hand wash recommended.Steam Iron."
# cleaned_text = remove_BS(me)

data_without_nan['BULLET_POINTS'] = data_without_nan['BULLET_POINTS'].apply(remove_BS)
data_without_nan.head()
# Out:
# /var/folders/6v/jd1m090n7m322nvh1vy2fbjh0000gp/T/ipykernel_92364/1645163889.py:7: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# /var/folders/6v/jd1m090n7m322nvh1vy2fbjh0000gp/T/ipykernel_92364/1645163889.py:7: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
#    PRODUCT_ID                                              TITLE  \
# 2     2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3     1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 5     2152929  HINS Metal Bucket Shape Plant Pot for Indoor &...
# 7     2026580  Delavala Self Adhesive Kitchen Backsplash Wall...
# ...

# %%
from bs4 import BeautifulSoup
import re
import string

def remove_BS(text):
    # Remove HTML Tags 
    soup = BeautifulSoup(text, "html.parser")
    cleaned_text = soup.get_text()

    # Remove Special Characters 
    pattern = r'[^a-zA-Z0-9\s]'
    cleaned_text = re.sub(pattern, '', cleaned_text)
    # return re.sub(pattern, '', cleaned_text)

    # Remove punctations
    text  = "".join([char for char in cleaned_text if char not in string.punctuation])
    text = re.sub('[0-9]+', '', text)
    cleaned_text = re.sub('\n' , "", text)

    return cleaned_text

# # Example usage
# html_text = "<p>This is an example <b>HTML</b> text with <a href='https://example.com'>link</a>.</p>"
# me = '<p><strong>!!!!!Aluminum Foil Stickers-good...... ???ASDASD...,,,,as.kitchen helper for mom and wife.&nbsp;</strong><br><br><strong>Specification: &nbsp;</strong><br><strong>'
# me = "â˜…Sizeï¼šXS=US (4-6) S=US(4-8), M=US(10-14), L=US(16-20), XL=US(18-22ï¼‰ï¼ŒOversized style sweatersï¼Œif between size, long torso choose size up.,â˜…Designï¼šTurtle cowl neckï¼Œlong batwing sleeveï¼Œhigh low split hemï¼Œsolid colorï¼Œtunic top sweaterï¼Œknitwear casual styleï¼Œoversized sweater.,â˜…Occasion: Outdoor wearing, Casual,Office; Great with leggings, high heels, boots etc,â˜…Material:The asymmetric hem sweater made of 50% viscose 30% nylon and 20% Ployesterï¼Œchunky sweaterï¼Œcasual comfy pulloversï¼ŒLILLUSORY high quality sweaters.,â˜…Washing Instruction: Hand wash recommended.Steam Iron."
# cleaned_text = remove_BS(me)

data_without_nan['TITLE'] = data_without_nan['TITLE'].apply(remove_BS)
data_without_nan.head()
# Out:
# /var/folders/6v/jd1m090n7m322nvh1vy2fbjh0000gp/T/ipykernel_92364/3597576925.py:7: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
#    PRODUCT_ID                                              TITLE  \
# 2     2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3     1594019  ALISHAH Womens Cotton Ankle Length Leggings Co...
# 5     2152929  HINS Metal Bucket Shape Plant Pot for Indoor  ...
# 7     2026580  Delavala Self Adhesive Kitchen Backsplash Wall...
# 9     2998633  Hexwell Essential oil for Home Fragrance Oil A...
#
#                                        BULLET_POINTS  \
# 2  Loud Dual Tone Trumpet Horn Compatible With SX...
# 3  Made By cotton and  Lycra which gives you  way...
# 5  Simple and elegant great for displaying indoor...
# 7  HIGH QUALITY PVC MATERIAL The kitchen aluminum...
# ...

# %%
import nltk

nltk.download('all')


from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# df = pd.read_csv("/train.csv")
# first_20_rows = df.head(20)


column_name = "TITLE"


data = data_without_nan[column_name].apply(str)


processed_data = []

# Process each row of data
for row in data:
    #individual words
    words = word_tokenize(row)

    # sw = list(sw,wds("eng"))
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.casefold() not in stop_words]

    processed_data.append(" ".join(words))


data_without_nan['processed_title'] = processed_data
# data_without_nan['DESCRIPTION'] = processed_data
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/jaliparthisaisujith/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/jaliparthisaisujith/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/jaliparthisaisujith/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/jaliparthisaisujith/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/jaliparthisaisujith/nltk_data...
# ...

# %%
data_without_nan['DESCRIPTION']
# Out:
# 2          Specifications Color Red Material Aluminium Vo...
# 3          AISHAH Womens Lycra Cotton Ankel Leggings Bran...
# 5          HINS Brings you the most Elegant Looking Pot w...
# 7          Aluminum Foil Stickersgood kitchen helper for ...
# 9          Transform your home workplace or hotel room in...
#                                  ...
# 2249686    COCOMIIWe transform amazing ideas and advanced...
# 2249689    This extra long Tall tShirt will be your favor...
# 2249694    Brand XVIEONR  Product name Fashion cute brooc...
# 2249695    Wall Clocks Are Very Attractive In Looks And E...
# 2249697    Skyjacker CSP Component Box For PNCPK Lift Kit...
# Name: DESCRIPTION, Length: 1038460, dtype: object

# %%
data_new_nannn = data_without_nan
data_new_nannn
# Out:
#          PRODUCT_ID                                              TITLE  \
# 2           2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3           1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 5           2152929  HINS Metal Bucket Shape Plant Pot for Indoor &...
# 7           2026580  Delavala Self Adhesive Kitchen Backsplash Wall...
# 9           2998633  Hexwell Essential oil for Home Fragrance Oil A...
# ...             ...                                                ...
# 2249686     1898841  Cocomii Holographic iPhone 11 Pro Case - Holog...
# 2249689     1616561  Have It Tall Men's Curved Hem Long Drop Tail T...
# 2249694     2766635  (3PCS) Goose Game Cute Cartoon Enamel Pins, Fu...
# 2249695     1987786  Kangroo Sweep Movement Printed Wooden Wall Clo...
# 2249697     1072666  Skyjacker C7360SP Component Box For PN[C7360PK...
#
#                                              BULLET_POINTS  \
# ...

# %%
data_without_nan['DESCRIPTION'][:5]
# Out:
# /var/folders/6v/jd1m090n7m322nvh1vy2fbjh0000gp/T/ipykernel_92364/1550589142.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data_without_nan['DESCRIPTION'][:5]
# 2    Specifications Color Red Material Aluminium Vo...
# 3    AISHAH Womens Lycra Cotton Ankel Leggings Bran...
# 5    HINS Brings you the most Elegant Looking Pot w...
# 7    Aluminum Foil Stickersgood kitchen helper for ...
# 9    Transform your home workplace or hotel room in...
# Name: DESCRIPTION, dtype: object

# %%
data_without_nan
# Out:
#          PRODUCT_ID                                              TITLE  \
# 2           2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3           1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 5           2152929  HINS Metal Bucket Shape Plant Pot for Indoor &...
# 7           2026580  Delavala Self Adhesive Kitchen Backsplash Wall...
# 9           2998633  Hexwell Essential oil for Home Fragrance Oil A...
# ...             ...                                                ...
# 2249686     1898841  Cocomii Holographic iPhone 11 Pro Case - Holog...
# 2249689     1616561  Have It Tall Men's Curved Hem Long Drop Tail T...
# 2249694     2766635  (3PCS) Goose Game Cute Cartoon Enamel Pins, Fu...
# 2249695     1987786  Kangroo Sweep Movement Printed Wooden Wall Clo...
# 2249697     1072666  Skyjacker C7360SP Component Box For PN[C7360PK...
#
#                                              BULLET_POINTS  \
# ...

# %%
data_without_nan.to_csv("Clean_data_without_nan.csv")
